# %%
from qiskit.visualization import circuit_drawer
from qiskit.visualization import utils

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.circuit.library import HGate
from qiskit.circuit.library import MCXGate
from qiskit_aer import Aer
from qiskit import *
from qiskit.visualization import plot_histogram

#####寄存
q_X = QuantumRegister(2, name='X')
q_Y = QuantumRegister(2, name='Y')
q_Z = QuantumRegister(2, name='Z')
q_F = QuantumRegister(1, name='F')
q_R = QuantumRegister(8, name='R')
q_G = QuantumRegister(8, name='G')
q_B = QuantumRegister(8, name='B')
#c_X = ClassicalRegister(2)
#c_Y = ClassicalRegister(2)
#c_Z = ClassicalRegister(3)
#c_F = ClassicalRegister(1)
#c_N = ClassicalRegister(3)




circuit = QuantumCircuit(q_X,q_Y,q_Z,q_F,q_R,q_G,q_B)# ,q_B,c_B，c_X,c_Y,c_Z,c_F,c_N



for h in range(6):
    circuit.append( HGate(),[h])
circuit.barrier()
gate7 = MCXGate(6,ctrl_state='000011')##(zyx)
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  15])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  16])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  17])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  18])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  19])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  20])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  21])#门的名称，控制位，控制目标
circuit.append(gate7, [0, 1 ,2, 3, 4, 5,  22])#门的名称，控制位，控制目标
circuit.barrier()


gate1 = MCXGate(6,ctrl_state='010111')
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  7])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  8])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  9])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  10])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  11])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  12])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  13])#门的名称，控制位，控制目标
circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  14])#门的名称，控制位，控制目标
circuit.barrier()


gate2 = MCXGate(6,ctrl_state='001100')
circuit.append(gate2, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.barrier()

gate3 = MCXGate(6,ctrl_state='110000')
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  7])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  8])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  9])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  10])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  11])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  12])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  13])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  14])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  15])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  16])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  17])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  18])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  19])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  20])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  21])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  22])#门的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  23])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  24])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  25])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  26])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  27])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  28])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  29])#的名称，控制位，控制目标
circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  30])#的名称，控制位，控制目标

circuit.barrier()





















# gate1 = MCXGate(7,ctrl_state='1110000')
# circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate1, [0, 1 ,2, 3, 4, 5,  6,8])#门的名称，控制位，控制目标
# 
# circuit.barrier()
# 
# gate2 = MCXGate(7,ctrl_state='1011100')
# circuit.append(gate2, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate2, [0, 1 ,2, 3, 4, 5,  6,9])#门的名称，控制位，控制目标
# 
# circuit.barrier()
# 
# gate3 = MCXGate(7,ctrl_state='1011000')
# circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  6,8])#门的名称，控制位，控制目标
# circuit.append(gate3, [0, 1 ,2, 3, 4, 5,  6,9])#门的名称，控制位，控制目标
# circuit.barrier()
# 
# gate4 = MCXGate(7,ctrl_state='1111111')
# circuit.append(gate4, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate4, [0, 1 ,2, 3, 4, 5,  6,10])#门的名称，控制位，控制目标
# 
# circuit.barrier()
# 
# gate5 = MCXGate(7,ctrl_state='0000000')
# circuit.append(gate5, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate5, [0, 1 ,2, 3, 4, 5,  6,8])#门的名称，控制位，控制目标
# circuit.append(gate5, [0, 1 ,2, 3, 4, 5,  6,10])#门的名称，控制位，控制目标
# circuit.barrier()
# gate6 = MCXGate(7,ctrl_state='0101010')
# circuit.append(gate6, [0, 1 ,2, 3, 4, 5,  6,7])#门的名称，控制位，控制目标
# circuit.append(gate6, [0, 1 ,2, 3, 4, 5,  6,9])#门的名称，控制位，控制目标
# circuit.append(gate6, [0, 1 ,2, 3, 4, 5,  6,10])#门的名称，控制位，控制目标

circuit.barrier()
#circuit.measure(q_N[1], c_N[1])
#circuit.measure(q_N[0], c_N[0])
#circuit.measure(q_N[2], c_N[2])
#circuit.measure(q_N[4], c_N[4])
#with circuit.if_test((c_N, 0b10))as else_:
#     circuit.reset(7) 
#with else_:
#    circuit.id(7) 
#circuit.barrier()
#circuit.measure(q_X, c_X)
#circuit.measure(q_Y, c_Y)
#circuit.measure(q_Z, c_Z)
#circuit.measure(q_F, c_F)

circuit.draw(output='mpl',reverse_bits=True,scale=0.4,fold=1000)
