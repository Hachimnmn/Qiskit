# %%
from qiskit_ibm_runtime import QiskitRuntimeService
#



from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.circuit.library import HGate
from qiskit.circuit.library import MCXGate
from qiskit_aer import Aer
from qiskit import *
from qiskit.visualization import plot_histogram


#####寄存
q_X = QuantumRegister(2, name='X')
q_Y = QuantumRegister(2, name='Y')
q_Z = QuantumRegister(2, name='Z')
q_F = QuantumRegister(1, name='F')
q_R = QuantumRegister(8, name='R')
q_G = QuantumRegister(8, name='G')
q_B = QuantumRegister(8, name='B')

c_X = ClassicalRegister(2)
c_Y = ClassicalRegister(2)
c_Z = ClassicalRegister(2)
c_F = ClassicalRegister(1)
c_R = ClassicalRegister(8)
c_G = ClassicalRegister(8)
c_B = ClassicalRegister(8)

circuit = QuantumCircuit(q_X,q_Y,q_Z,q_F,q_R,q_G,q_B,c_X,c_Y,c_Z,c_F,c_R,c_G,c_B)# ,q_B,c_B

##HHHHHHHHHHHHHHHHHHHHH
for h in range(6):
    circuit.append( HGate(),[h])
circuit.barrier()
#Not
gateG = MCXGate(6,ctrl_state='001100')
#N-cnot
#GGGGGGGGGGGGGGGGGGG
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  15])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  16])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  17])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  18])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  19])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  20])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  21])#门的名称，控制位，控制目标
circuit.append(gateG, [0, 1 ,2, 3, 4, 5,  22])#门的名称，控制位，控制目标
circuit.barrier()
#RRRRRRRRRRR
gateR = MCXGate(6,ctrl_state='101110')
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  7])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  8])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  9])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  10])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  11])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  12])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  13])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  14])#门的名称，控制位，控制目标
circuit.barrier()

#BBBBBBBBBBBBBBBBBBBB
gateR = MCXGate(6,ctrl_state='111011')
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  23])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  24])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  25])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  26])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  27])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  28])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  29])#门的名称，控制位，控制目标
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  30])#门的名称，控制位，控制目标
circuit.barrier()

#KKKKKKKKKKKKKKKKKKK
gateR = MCXGate(6,ctrl_state='000011')
circuit.append(gateR, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.barrier()

#CCCCCCC
gateC = MCXGate(6,ctrl_state='001000')
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  15])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  16])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  17])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  18])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  19])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  20])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  21])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  22])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  23])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  24])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  25])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  26])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  27])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  28])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  29])#门的名称，控制位，控制目标
circuit.append(gateC, [0, 1 ,2, 3, 4, 5,  30])#门的名称，控制位，控制目标
circuit.barrier()

#MMMMMMM
gateM = MCXGate(6,ctrl_state='111010')
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  7])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  8])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  9])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  10])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  11])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  12])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  13])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  14])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  23])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  24])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  25])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  26])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  27])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  28])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  29])#门的名称，控制位，控制目标
circuit.append(gateM, [0, 1 ,2, 3, 4, 5,  30])#门的名称，控制位，控制目标
circuit.barrier()

#YYYYYYYYYYY
gateY = MCXGate(6,ctrl_state='100000')
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  6])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  7])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  8])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  9])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  10])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  11])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  12])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  13])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  14])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  15])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  16])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  17])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  18])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  19])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  20])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  21])#门的名称，控制位，控制目标
circuit.append(gateY, [0, 1 ,2, 3, 4, 5,  22])#门的名称，控制位，控制目标
circuit.barrier()
#N-CE
circuit.measure(q_X,c_X)
circuit.measure(q_Y,c_Y)
circuit.measure(q_Z,c_Z)
circuit.measure(q_F,c_F)
circuit.measure(q_R,c_R)
circuit.measure(q_G,c_G)
circuit.measure(q_B,c_B)

service = QiskitRuntimeService()
backend = service.get_backend("ibmq_qasm_simulator")
tqc = transpile(circuit, backend)
counts = backend.run(tqc, shots=100).result().get_counts()
with open('ALL.txt', 'w') as file:
    for key, value in counts.items():
        file.write(f"{key}: {value}\n")
print(counts)
# Draw the circuit
options = Options(max_execution_time=7200)
circuit.draw(output='mpl',reverse_bits=True,scale=0.45,fold=100)
# Out:
# runtime_job._start_websocket_client:WARNING:2024-04-08 17:44:32,844: An error occurred while streaming results from the server for job co9rord0cpthsc8uppjg:
# Traceback (most recent call last):
#   File "C:\Users\Hachi\.conda\envs\Nqis\lib\site-packages\qiskit_ibm_runtime\runtime_job.py", line 549, in _start_websocket_client
#     self._ws_client.job_results()
#   File "C:\Users\Hachi\.conda\envs\Nqis\lib\site-packages\qiskit_ibm_runtime\api\clients\runtime_ws.py", line 70, in job_results
#     self.stream(url=url, retries=max_retries, backoff_factor=backoff_factor)
#   File "C:\Users\Hachi\.conda\envs\Nqis\lib\site-packages\qiskit_ibm_runtime\api\clients\base_websocket_client.py", line 222, in stream
#     raise WebsocketError(error_message)
# ...

# %%
# 生成数字并写入文件
with open('numbers.txt', 'w') as file:
    for i in range(1, 1000001):
        file.write(str(i) + '\n')

print("文件已生成。")
# Out:
# 文件已生成。

# %%
import os
print(os.path.abspath('.'))
# Out:
# C:\Users\Hachi
